# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
drugcomtest_df = pd.read_csv('../data/raw/drugsComTest_raw.tsv', sep='\t')
drugcomtrain_df = pd.read_csv('../data/raw/drugsComTrain_raw.tsv', sep='\t')

# %%
print(np.mean(drugcomtest_df['rating'])
# Out:
#        Unnamed: 0                       drugName  \
# 0          163740                    Mirtazapine
# 1          206473                     Mesalamine
# 2          159672                        Bactrim
# 3           39293                       Contrave
# 4           97768                Cyclafem 1 / 35
# 5          208087                        Zyclara
# 6          215892                         Copper
# 7          169852                  Amitriptyline
# 8           23295                      Methadone
# 9           71428                         Levora
# 10         196802                     Paroxetine
# 11          31947                     Miconazole
# 12           4907                         Belviq
# 13          66736                       Seroquel
# 14          97013                         Ambien
# 15         213376                        Nuvigil
# 16         151674                        Chantix
# 17          33173          Microgestin Fe 1 / 20
# ...
